# %%
from rest.api import EdgewaterAPI
from models import Item, Inventory, ItemType
import pandas as pd

edgewater = EdgewaterAPI()

# %%
df = edgewater._get_orders_full()
for col in df.columns:
    print(col)
# Out:
# 2025-12-06 15:17:19,737 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 15:17:19,738 INFO sqlalchemy.engine.Engine SELECT `T_OrderItems`.`OrderItemID` AS `T_OrderItems_OrderItemID`, `T_OrderItems`.`OrderID` AS `T_OrderItems_OrderID`, `T_OrderItems`.`ItemID` AS `T_OrderItems_ItemID`, `T_OrderItems`.`ItemCode` AS `T_OrderItems_ItemCode`, `T_OrderItems`.`OrderItemTypeID` AS `T_OrderItems_OrderItemTypeID`, `T_OrderItems`.`Unit` AS `T_OrderItems_Unit`, `T_OrderItems`.`UnitPrice` AS `T_OrderItems_UnitPrice`, `T_OrderItems`.`NumberOfUnits` AS `T_OrderItems_NumberOfUnits`, `T_OrderItems`.`Received` AS `T_OrderItems_Received`, `T_OrderItems`.`OrderNote` AS `T_OrderItems_OrderNote`, `T_OrderItems`.`OrderComments` AS `T_OrderItems_OrderComments`, `T_OrderItems`.`Leftover` AS `T_OrderItems_Leftover`, `T_OrderItems`.`ToOrder` AS `T_OrderItems_ToOrder`
# FROM `T_OrderItems`
# 2025-12-06 15:17:19,739 INFO sqlalchemy.engine.Engine [cached since 114.3s ago] {}
# 2025-12-06 15:17:20.226 | INFO     | rest.api:_get_all:146 - Retrieved 38580 records from T_OrderItems
# 2025-12-06 15:17:20,286 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 15:17:20,453 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 15:17:20,454 INFO sqlalchemy.engine.Engine SELECT `T_Orders`.`OrderID` AS `T_Orders_OrderID`, `T_Orders`.`GrowingSeasonID` AS `T_Orders_GrowingSeasonID`, `T_Orders`.`DatePlaced` AS `T_Orders_DatePlaced`, `T_Orders`.`DateDue` AS `T_Orders_DateDue`, `T_Orders`.`DateReceived` AS `T_Orders_DateReceived`, `T_Orders`.`SupplierID` AS `T_Orders_SupplierID`, `T_Orders`.`OrderNumber` AS `T_Orders_OrderNumber`, `T_Orders`.`ShipperID` AS `T_Orders_ShipperID`, `T_Orders`.`TrackingNumber` AS `T_Orders_TrackingNumber`, `T_Orders`.`OrderComments` AS `T_Orders_OrderComments`, `T_Orders`.`TotalCost` AS `T_Orders_TotalCost`, `T_Orders`.`GrowingSeason` AS `T_Orders_GrowingSeason`, `T_Orders`.`BrokerID` AS `T_Orders_BrokerID`
# FROM `T_Orders`
# 2025-12-06 15:17:20,454 INFO sqlalchemy.engine.Engine [cached since 114.3s ago] {}
# 2025-12-06 15:17:20.470 | INFO     | rest.api:_get_all:146 - Retrieved 1562 records from T_Orders
# 2025-12-06 15:17:20,474 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 15:17:20,480 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 15:17:20,480 INFO sqlalchemy.engine.Engine SELECT `T_OrderItemTypes`.`OrderItemTypeID` AS `T_OrderItemTypes_OrderItemTypeID`, `T_OrderItemTypes`.`OrderItemType` AS `T_OrderItemTypes_OrderItemType`
# FROM `T_OrderItemTypes`
# 2025-12-06 15:17:20,480 INFO sqlalchemy.engine.Engine [cached since 114.3s ago] {}
# 2025-12-06 15:17:20.482 | INFO     | rest.api:_get_all:146 - Retrieved 36 records from T_OrderItemTypes
# 2025-12-06 15:17:20,482 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 15:17:20,483 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 15:17:20,483 INFO sqlalchemy.engine.Engine SELECT `T_OrderNotes`.`OrderNoteID` AS `T_OrderNotes_OrderNoteID`, `T_OrderNotes`.`OrderNote` AS `T_OrderNotes_OrderNote`
# FROM `T_OrderNotes`
# 2025-12-06 15:17:20,484 INFO sqlalchemy.engine.Engine [cached since 114.3s ago] {}
# 2025-12-06 15:17:20.484 | INFO     | rest.api:_get_all:146 - Retrieved 6 records from T_OrderNotes
# 2025-12-06 15:17:20,485 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 15:17:20,486 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 15:17:20,486 INFO sqlalchemy.engine.Engine SELECT `T_Brokers`.`BrokerID` AS `T_Brokers_BrokerID`, `T_Brokers`.`Broker` AS `T_Brokers_Broker`, `T_Brokers`.`BrokerComments` AS `T_Brokers_BrokerComments`
# FROM `T_Brokers`
# 2025-12-06 15:17:20,487 INFO sqlalchemy.engine.Engine [cached since 114.3s ago] {}
# 2025-12-06 15:17:20.487 | INFO     | rest.api:_get_all:146 - Retrieved 3 records from T_Brokers
# 2025-12-06 15:17:20,488 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 15:17:20,489 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 15:17:20,489 INFO sqlalchemy.engine.Engine SELECT `T_Shippers`.`ShipperID` AS `T_Shippers_ShipperID`, `T_Shippers`.`Shipper` AS `T_Shippers_Shipper`, `T_Shippers`.`AccountNumber` AS `T_Shippers_AccountNumber`, `T_Shippers`.`Phone` AS `T_Shippers_Phone`, `T_Shippers`.`ContactPerson` AS `T_Shippers_ContactPerson`, `T_Shippers`.`Address1` AS `T_Shippers_Address1`, `T_Shippers`.`Address2` AS `T_Shippers_Address2`, `T_Shippers`.`City` AS `T_Shippers_City`, `T_Shippers`.`State` AS `T_Shippers_State`, `T_Shippers`.`Zip` AS `T_Shippers_Zip`, `T_Shippers`.`ShipperComments` AS `T_Shippers_ShipperComments`
# FROM `T_Shippers`
# 2025-12-06 15:17:20,489 INFO sqlalchemy.engine.Engine [cached since 114.3s ago] {}
# 2025-12-06 15:17:20.490 | INFO     | rest.api:_get_all:146 - Retrieved 8 records from T_Shippers
# 2025-12-06 15:17:20,491 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 15:17:20,492 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 15:17:20,492 INFO sqlalchemy.engine.Engine SELECT `T_Suppliers`.`SupplierID` AS `T_Suppliers_SupplierID`, `T_Suppliers`.`Supplier` AS `T_Suppliers_Supplier`, `T_Suppliers`.`AccountNumber` AS `T_Suppliers_AccountNumber`, `T_Suppliers`.`Phone` AS `T_Suppliers_Phone`, `T_Suppliers`.`Fax` AS `T_Suppliers_Fax`, `T_Suppliers`.`WebSite` AS `T_Suppliers_WebSite`, `T_Suppliers`.`Email` AS `T_Suppliers_Email`, `T_Suppliers`.`ContactPerson` AS `T_Suppliers_ContactPerson`, `T_Suppliers`.`Address1` AS `T_Suppliers_Address1`, `T_Suppliers`.`Address2` AS `T_Suppliers_Address2`, `T_Suppliers`.`City` AS `T_Suppliers_City`, `T_Suppliers`.`State` AS `T_Suppliers_State`, `T_Suppliers`.`Zip` AS `T_Suppliers_Zip`, `T_Suppliers`.`SupplierComments` AS `T_Suppliers_SupplierComments`, `T_Suppliers`.`SupplierType` AS `T_Suppliers_SupplierType`
# FROM `T_Suppliers`
# 2025-12-06 15:17:20,492 INFO sqlalchemy.engine.Engine [cached since 114.3s ago] {}
# 2025-12-06 15:17:20.495 | INFO     | rest.api:_get_all:146 - Retrieved 230 records from T_Suppliers
# 2025-12-06 15:17:20,496 INFO sqlalchemy.engine.Engine COMMIT
# OrderItemID
# OrderID
# ItemID
# OrderItemTypeID
# UnitPrice
# Received
# OrderComments_x
# ToOrder
# ItemCode
# Unit
# NumberOfUnits
# OrderNote_x
# Leftover
# DatePlaced
# DateReceived
# OrderNumber
# TrackingNumber
# OrderComments_y
# GrowingSeason
# GrowingSeasonID
# DateDue
# SupplierID
# ShipperID
# TotalCost
# BrokerID
# OrderItemType
# OrderNoteID
# OrderNote_y
# BrokerComments
# Broker
# Shipper
# AccountNumber_x
# ContactPerson_x
# Address2_x
# State_x
# ShipperComments
# Phone_x
# Address1_x
# City_x
# Zip_x
# Phone_y
# WebSite
# ContactPerson_y
# Address2_y
# State_y
# SupplierComments
# AccountNumber_y
# Supplier
# Fax
# Email
# Address1_y
# City_y
# Zip_y
# SupplierType

# %%
df =edgewater._get_plant_list_full()
df
# Out:
# 2025-12-06 14:41:57,981 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-12-06 14:41:57,981 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-06 14:41:57,983 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-12-06 14:41:57,983 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-06 14:41:57,984 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-12-06 14:41:57,984 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-06 14:41:57,985 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:57,987 INFO sqlalchemy.engine.Engine SELECT `T_Items`.`ItemID` AS `T_Items_ItemID`, `T_Items`.`Inactive` AS `T_Items_Inactive`, `T_Items`.`Item` AS `T_Items_Item`, `T_Items`.`Variety` AS `T_Items_Variety`, `T_Items`.`Color` AS `T_Items_Color`, `T_Items`.`ShouldStock` AS `T_Items_ShouldStock`, `T_Items`.`TypeID` AS `T_Items_TypeID`, `T_Items`.`LabelDescription` AS `T_Items_LabelDescription`, `T_Items`.`Definition` AS `T_Items_Definition`, `T_Items`.`PictureLayout` AS `T_Items_PictureLayout`, `T_Items`.`PictureLink` AS `T_Items_PictureLink`, `T_Items`.`SunConditions` AS `T_Items_SunConditions`
# FROM `T_Items`
# 2025-12-06 14:41:57,987 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {}
# 2025-12-06 14:41:58.086 | INFO     | rest.api:_get_all:146 - Retrieved 7254 records from T_Items
# 2025-12-06 14:41:58,096 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,116 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,116 INFO sqlalchemy.engine.Engine SELECT `T_Inventory`.`InventoryID` AS `T_Inventory_InventoryID`, `T_Inventory`.`DateCounted` AS `T_Inventory_DateCounted`, `T_Inventory`.`ItemID` AS `T_Inventory_ItemID`, `T_Inventory`.`UnitID` AS `T_Inventory_UnitID`, `T_Inventory`.`NumberOfUnits` AS `T_Inventory_NumberOfUnits`, `T_Inventory`.`InventoryComments` AS `T_Inventory_InventoryComments`
# FROM `T_Inventory`
# 2025-12-06 14:41:58,117 INFO sqlalchemy.engine.Engine [generated in 0.00025s] {}
# 2025-12-06 14:41:58.151 | INFO     | rest.api:_get_all:146 - Retrieved 5216 records from T_Inventory
# 2025-12-06 14:41:58,159 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,170 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,171 INFO sqlalchemy.engine.Engine SELECT `T_Units`.`UnitID` AS `T_Units_UnitID`, `T_Units`.`UnitType` AS `T_Units_UnitType`, `T_Units`.`UnitSize` AS `T_Units_UnitSize`, `T_Units`.`UnitCategoryID` AS `T_Units_UnitCategoryID`
# FROM `T_Units`
# 2025-12-06 14:41:58,171 INFO sqlalchemy.engine.Engine [generated in 0.00023s] {}
# 2025-12-06 14:41:58.172 | INFO     | rest.api:_get_all:146 - Retrieved 61 records from T_Units
# 2025-12-06 14:41:58,173 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,174 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,175 INFO sqlalchemy.engine.Engine SELECT `T_UnitCategory`.`UnitCategoryID` AS `T_UnitCategory_UnitCategoryID`, `T_UnitCategory`.`UnitCategory` AS `T_UnitCategory_UnitCategory`
# FROM `T_UnitCategory`
# 2025-12-06 14:41:58,175 INFO sqlalchemy.engine.Engine [generated in 0.00021s] {}
# 2025-12-06 14:41:58.176 | INFO     | rest.api:_get_all:146 - Retrieved 4 records from T_UnitCategory
# 2025-12-06 14:41:58,176 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,177 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,178 INFO sqlalchemy.engine.Engine SELECT `T_ItemType`.`TypeID` AS `T_ItemType_TypeID`, `T_ItemType`.`Type` AS `T_ItemType_Type`
# FROM `T_ItemType`
# 2025-12-06 14:41:58,178 INFO sqlalchemy.engine.Engine [generated in 0.00020s] {}
# 2025-12-06 14:41:58.179 | INFO     | rest.api:_get_all:146 - Retrieved 9 records from T_ItemType
# 2025-12-06 14:41:58,179 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58.192 | WARNING  | rest.api:_get_plant_list_full:295 - UnitCategory column not found in combined3
#        Inactive                Item   Color  TypeID Definition PictureLink  \
# 1735      False     Salvia nemorosa    Blue     7.0       None        None
# 10362     False  Mertensia maritima    None     7.0       None        None
# 919       False            Clematis   White     7.0       None        None
# 7316      False               Peony  Yellow     7.0       None        None
# 7323      False    Campsis radicans     Red     7.0       None        None
# ...         ...                 ...     ...     ...        ...         ...
# 10585     False     Setaria italica    None     6.0       None        None
# 10586     False            Ageratum    None     6.0       None        None
# 10587     False              Zinnia     Mix     6.0       None        None
# 10588     False              Cleome    None     6.0       None        None
# 10589     False                None    None     0.0       None        None
#
#           SunConditions  ItemID                   Variety  ShouldStock  ...  \
# 1735   part-sun_sun.jpg    1138                 May Night        False  ...
# 10362           sun.jpg    8667             "Oyster Leaf"        False  ...
# 919    part-sun_sun.jpg     887  Terniflora  (paniculata)        False  ...
# 7316          blank.jpg    6003            Bartzella Itoh        False  ...
# 7323          blank.jpg    6004                  Flamenco        False  ...
# ...                 ...     ...                       ...          ...  ...
# 10585           sun.jpg    8895                 Limelight        False  ...
# 10586           sun.jpg    8896                Aloha Blue        False  ...
# 10587           sun.jpg    8897                Queen Lime        False  ...
# 10588           sun.jpg    8898           Sparkler Purple        False  ...
# 10589              None    8899                      None        False  ...
#
#       PictureLayout          DateCounted NumberOfUnits InventoryID  UnitID  \
# 1735           None  2516-10-01 00:00:00            17      4041.0    19.0
# 10362          None  2024-11-07 00:00:00            29      5227.0    37.0
# 919            None  2024-11-07 00:00:00            38      5143.0    48.0
# 7316           None  2024-11-07 00:00:00             3      5187.0    20.0
# 7323           None  2024-11-07 00:00:00             5      5150.0    20.0
# ...             ...                  ...           ...         ...     ...
# 10585          None                 None          None         NaN     NaN
# 10586          None                 None          None         NaN     NaN
# 10587          None                 None          None         NaN     NaN
# 10588          None                 None          None         NaN     NaN
# 10589          None                 None          None         NaN     NaN
#
#        InventoryComments        Type UnitCategoryID    UnitType UnitSize
# 1735                None   Perennial            1.0  Belden Pot       5"
# 10362               None   Perennial            4.0         Pot     4.5"
# 919                 None   Perennial            4.0       Janor   Gallon
# 7316                None   Perennial            4.0         Pot   Gallon
# 7323                None   Perennial            4.0         Pot   Gallon
# ...                  ...         ...            ...         ...      ...
# 10585                NaN      Annual            NaN         NaN      NaN
# 10586                NaN      Annual            NaN         NaN      NaN
# 10587                NaN      Annual            NaN         NaN      NaN
# 10588                NaN      Annual            NaN         NaN      NaN
# 10589                NaN  Unassigned            NaN         NaN      NaN
#
# [10590 rows x 21 columns]

# %%
df1 = edgewater.get_plant_list_display()
df1
# Out:
# 2025-12-06 14:41:58,226 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,233 INFO sqlalchemy.engine.Engine SELECT `T_Items`.`ItemID` AS `T_Items_ItemID`, `T_Items`.`Inactive` AS `T_Items_Inactive`, `T_Items`.`Item` AS `T_Items_Item`, `T_Items`.`Variety` AS `T_Items_Variety`, `T_Items`.`Color` AS `T_Items_Color`, `T_Items`.`ShouldStock` AS `T_Items_ShouldStock`, `T_Items`.`TypeID` AS `T_Items_TypeID`, `T_Items`.`LabelDescription` AS `T_Items_LabelDescription`, `T_Items`.`Definition` AS `T_Items_Definition`, `T_Items`.`PictureLayout` AS `T_Items_PictureLayout`, `T_Items`.`PictureLink` AS `T_Items_PictureLink`, `T_Items`.`SunConditions` AS `T_Items_SunConditions`
# FROM `T_Items`
# 2025-12-06 14:41:58,250 INFO sqlalchemy.engine.Engine [cached since 0.2637s ago] {}
# 2025-12-06 14:41:58.361 | INFO     | rest.api:_get_all:146 - Retrieved 7254 records from T_Items
# 2025-12-06 14:41:58,372 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,391 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,392 INFO sqlalchemy.engine.Engine SELECT `T_Inventory`.`InventoryID` AS `T_Inventory_InventoryID`, `T_Inventory`.`DateCounted` AS `T_Inventory_DateCounted`, `T_Inventory`.`ItemID` AS `T_Inventory_ItemID`, `T_Inventory`.`UnitID` AS `T_Inventory_UnitID`, `T_Inventory`.`NumberOfUnits` AS `T_Inventory_NumberOfUnits`, `T_Inventory`.`InventoryComments` AS `T_Inventory_InventoryComments`
# FROM `T_Inventory`
# 2025-12-06 14:41:58,392 INFO sqlalchemy.engine.Engine [cached since 0.2755s ago] {}
# 2025-12-06 14:41:58.466 | INFO     | rest.api:_get_all:146 - Retrieved 5216 records from T_Inventory
# 2025-12-06 14:41:58,477 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,491 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,492 INFO sqlalchemy.engine.Engine SELECT `T_Units`.`UnitID` AS `T_Units_UnitID`, `T_Units`.`UnitType` AS `T_Units_UnitType`, `T_Units`.`UnitSize` AS `T_Units_UnitSize`, `T_Units`.`UnitCategoryID` AS `T_Units_UnitCategoryID`
# FROM `T_Units`
# 2025-12-06 14:41:58,492 INFO sqlalchemy.engine.Engine [cached since 0.3211s ago] {}
# 2025-12-06 14:41:58.494 | INFO     | rest.api:_get_all:146 - Retrieved 61 records from T_Units
# 2025-12-06 14:41:58,495 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,501 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,501 INFO sqlalchemy.engine.Engine SELECT `T_UnitCategory`.`UnitCategoryID` AS `T_UnitCategory_UnitCategoryID`, `T_UnitCategory`.`UnitCategory` AS `T_UnitCategory_UnitCategory`
# FROM `T_UnitCategory`
# 2025-12-06 14:41:58,502 INFO sqlalchemy.engine.Engine [cached since 0.3269s ago] {}
# 2025-12-06 14:41:58.504 | INFO     | rest.api:_get_all:146 - Retrieved 4 records from T_UnitCategory
# 2025-12-06 14:41:58,504 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,506 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,506 INFO sqlalchemy.engine.Engine SELECT `T_ItemType`.`TypeID` AS `T_ItemType_TypeID`, `T_ItemType`.`Type` AS `T_ItemType_Type`
# FROM `T_ItemType`
# 2025-12-06 14:41:58,507 INFO sqlalchemy.engine.Engine [cached since 0.3288s ago] {}
# 2025-12-06 14:41:58.509 | INFO     | rest.api:_get_all:146 - Retrieved 9 records from T_ItemType
# 2025-12-06 14:41:58,509 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58.524 | WARNING  | rest.api:_get_plant_list_full:295 - UnitCategory column not found in combined3
#       NumberOfUnits          DateCounted                Item  \
# 1735             17  2516-10-01 00:00:00     Salvia nemorosa
# 10362            29  2024-11-07 00:00:00  Mertensia maritima
# 919              38  2024-11-07 00:00:00            Clematis
# 7316              3  2024-11-07 00:00:00               Peony
# 7323              5  2024-11-07 00:00:00    Campsis radicans
# ...             ...                  ...                 ...
# 10585           NaN                  NaN     Setaria italica
# 10586           NaN                  NaN            Ageratum
# 10587           NaN                  NaN              Zinnia
# 10588           NaN                  NaN              Cleome
# 10589           NaN                  NaN                None
#
#                         Variety Definition   Color        Type  \
# 1735                  May Night       None    Blue   Perennial
# 10362             "Oyster Leaf"       None    None   Perennial
# 919    Terniflora  (paniculata)       None   White   Perennial
# 7316             Bartzella Itoh       None  Yellow   Perennial
# 7323                   Flamenco       None     Red   Perennial
# ...                         ...        ...     ...         ...
# 10585                 Limelight       None    None      Annual
# 10586                Aloha Blue       None    None      Annual
# 10587                Queen Lime       None     Mix      Annual
# 10588           Sparkler Purple       None    None      Annual
# 10589                      None       None    None  Unassigned
#
#           SunConditions UnitSize    UnitType  Inactive  ShouldStock  \
# 1735   part-sun_sun.jpg       5"  Belden Pot     False        False
# 10362           sun.jpg     4.5"         Pot     False        False
# 919    part-sun_sun.jpg   Gallon       Janor     False        False
# 7316          blank.jpg   Gallon         Pot     False        False
# 7323          blank.jpg   Gallon         Pot     False        False
# ...                 ...      ...         ...       ...          ...
# 10585           sun.jpg      NaN         NaN     False        False
# 10586           sun.jpg      NaN         NaN     False        False
# 10587           sun.jpg      NaN         NaN     False        False
# 10588           sun.jpg      NaN         NaN     False        False
# 10589              None      NaN         NaN     False        False
#
#                                         LabelDescription InventoryComments
# 1735   18" Blue spkes. Perennial Plant of the Year se...              None
# 10362  The perennial plant flowers initially reddish ...              None
# 919    Ht. 10-20' BloomsSept.-Oct.Prune in early spri...              None
# 7316   Very large, bright yellow double blossoms stan...              None
# 7323   Ht. 30'  deciduous climbing vine that is easy ...              None
# ...                                                  ...               ...
# 10585  Ht. 36-60" The vibrant lime color is enough to...               NaN
# 10586  Ht. 5-8" Aloha is early to flower and an excel...               NaN
# 10587  Ht. 36" The Queen Lime Zinnia Mixture is a mix...               NaN
# 10588  Ht. 36-44" Heat-loving annual holds up to summ...               NaN
# 10589                                               None               NaN
#
# [10590 rows x 14 columns]

# %%
df2 = edgewater._get_plantings_full()
df2cols = df2.columns.tolist()
df2cols
# Out:
# 2025-12-06 14:41:58,550 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,551 INFO sqlalchemy.engine.Engine SELECT `T_Plantings`.`PlantingID` AS `T_Plantings_PlantingID`, `T_Plantings`.`DatePlanted` AS `T_Plantings_DatePlanted`, `T_Plantings`.`ItemID` AS `T_Plantings_ItemID`, `T_Plantings`.`UnitID` AS `T_Plantings_UnitID`, `T_Plantings`.`NumberOfUnits` AS `T_Plantings_NumberOfUnits`, `T_Plantings`.`PlantingComments` AS `T_Plantings_PlantingComments`
# FROM `T_Plantings`
# 2025-12-06 14:41:58,552 INFO sqlalchemy.engine.Engine [generated in 0.00099s] {}
# 2025-12-06 14:41:58.847 | INFO     | rest.api:_get_all:146 - Retrieved 19098 records from T_Plantings
# 2025-12-06 14:41:58,873 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:58,943 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:58,943 INFO sqlalchemy.engine.Engine SELECT `T_Items`.`ItemID` AS `T_Items_ItemID`, `T_Items`.`Inactive` AS `T_Items_Inactive`, `T_Items`.`Item` AS `T_Items_Item`, `T_Items`.`Variety` AS `T_Items_Variety`, `T_Items`.`Color` AS `T_Items_Color`, `T_Items`.`ShouldStock` AS `T_Items_ShouldStock`, `T_Items`.`TypeID` AS `T_Items_TypeID`, `T_Items`.`LabelDescription` AS `T_Items_LabelDescription`, `T_Items`.`Definition` AS `T_Items_Definition`, `T_Items`.`PictureLayout` AS `T_Items_PictureLayout`, `T_Items`.`PictureLink` AS `T_Items_PictureLink`, `T_Items`.`SunConditions` AS `T_Items_SunConditions`
# FROM `T_Items`
# 2025-12-06 14:41:58,944 INFO sqlalchemy.engine.Engine [cached since 0.957s ago] {}
# 2025-12-06 14:41:59.041 | INFO     | rest.api:_get_all:146 - Retrieved 7254 records from T_Items
# 2025-12-06 14:41:59,051 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:59,074 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:59,074 INFO sqlalchemy.engine.Engine SELECT `T_Units`.`UnitID` AS `T_Units_UnitID`, `T_Units`.`UnitType` AS `T_Units_UnitType`, `T_Units`.`UnitSize` AS `T_Units_UnitSize`, `T_Units`.`UnitCategoryID` AS `T_Units_UnitCategoryID`
# FROM `T_Units`
# 2025-12-06 14:41:59,075 INFO sqlalchemy.engine.Engine [cached since 0.9038s ago] {}
# 2025-12-06 14:41:59.076 | INFO     | rest.api:_get_all:146 - Retrieved 61 records from T_Units
# 2025-12-06 14:41:59,077 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:59,079 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:59,079 INFO sqlalchemy.engine.Engine SELECT `T_UnitCategory`.`UnitCategoryID` AS `T_UnitCategory_UnitCategoryID`, `T_UnitCategory`.`UnitCategory` AS `T_UnitCategory_UnitCategory`
# FROM `T_UnitCategory`
# 2025-12-06 14:41:59,079 INFO sqlalchemy.engine.Engine [cached since 0.9044s ago] {}
# 2025-12-06 14:41:59.080 | INFO     | rest.api:_get_all:146 - Retrieved 4 records from T_UnitCategory
# 2025-12-06 14:41:59,080 INFO sqlalchemy.engine.Engine COMMIT
# ['DatePlanted',
#  'ItemID',
#  'NumberOfUnits',
#  'PlantingID',
#  'UnitID',
#  'PlantingComments',
#  'Inactive',
#  'Item',
#  'Color',
#  'TypeID',
#  'Definition',
#  'PictureLink',
#  'SunConditions',
#  'Variety',
#  'ShouldStock',
#  'LabelDescription',
#  'PictureLayout',
#  'UnitCategoryID',
#  'UnitType',
#  'UnitSize',
#  'UnitCategory']

# %%
edgewater.get_plantings_display()
# Out:
# 2025-12-06 14:41:59,122 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:59,123 INFO sqlalchemy.engine.Engine SELECT `T_Plantings`.`PlantingID` AS `T_Plantings_PlantingID`, `T_Plantings`.`DatePlanted` AS `T_Plantings_DatePlanted`, `T_Plantings`.`ItemID` AS `T_Plantings_ItemID`, `T_Plantings`.`UnitID` AS `T_Plantings_UnitID`, `T_Plantings`.`NumberOfUnits` AS `T_Plantings_NumberOfUnits`, `T_Plantings`.`PlantingComments` AS `T_Plantings_PlantingComments`
# FROM `T_Plantings`
# 2025-12-06 14:41:59,123 INFO sqlalchemy.engine.Engine [cached since 0.5718s ago] {}
# 2025-12-06 14:41:59.369 | INFO     | rest.api:_get_all:146 - Retrieved 19098 records from T_Plantings
# 2025-12-06 14:41:59,395 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:59,439 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:59,439 INFO sqlalchemy.engine.Engine SELECT `T_Items`.`ItemID` AS `T_Items_ItemID`, `T_Items`.`Inactive` AS `T_Items_Inactive`, `T_Items`.`Item` AS `T_Items_Item`, `T_Items`.`Variety` AS `T_Items_Variety`, `T_Items`.`Color` AS `T_Items_Color`, `T_Items`.`ShouldStock` AS `T_Items_ShouldStock`, `T_Items`.`TypeID` AS `T_Items_TypeID`, `T_Items`.`LabelDescription` AS `T_Items_LabelDescription`, `T_Items`.`Definition` AS `T_Items_Definition`, `T_Items`.`PictureLayout` AS `T_Items_PictureLayout`, `T_Items`.`PictureLink` AS `T_Items_PictureLink`, `T_Items`.`SunConditions` AS `T_Items_SunConditions`
# FROM `T_Items`
# 2025-12-06 14:41:59,439 INFO sqlalchemy.engine.Engine [cached since 1.453s ago] {}
# 2025-12-06 14:41:59.538 | INFO     | rest.api:_get_all:146 - Retrieved 7254 records from T_Items
# 2025-12-06 14:41:59,548 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:59,570 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:59,571 INFO sqlalchemy.engine.Engine SELECT `T_Units`.`UnitID` AS `T_Units_UnitID`, `T_Units`.`UnitType` AS `T_Units_UnitType`, `T_Units`.`UnitSize` AS `T_Units_UnitSize`, `T_Units`.`UnitCategoryID` AS `T_Units_UnitCategoryID`
# FROM `T_Units`
# 2025-12-06 14:41:59,571 INFO sqlalchemy.engine.Engine [cached since 1.4s ago] {}
# 2025-12-06 14:41:59.573 | INFO     | rest.api:_get_all:146 - Retrieved 61 records from T_Units
# 2025-12-06 14:41:59,574 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:41:59,575 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:41:59,575 INFO sqlalchemy.engine.Engine SELECT `T_UnitCategory`.`UnitCategoryID` AS `T_UnitCategory_UnitCategoryID`, `T_UnitCategory`.`UnitCategory` AS `T_UnitCategory_UnitCategory`
# FROM `T_UnitCategory`
# 2025-12-06 14:41:59,576 INFO sqlalchemy.engine.Engine [cached since 1.401s ago] {}
# 2025-12-06 14:41:59.576 | INFO     | rest.api:_get_all:146 - Retrieved 4 records from T_UnitCategory
# 2025-12-06 14:41:59,577 INFO sqlalchemy.engine.Engine COMMIT
#        PlantingID NumberOfUnits             Item       Variety   Color  \
# 18482       19070             2           Zinnia     Profusion  Cherry
# 18479       19067        3 8/10       Nasturtium        Alaska     Mix
# 18480       19068        1 3/10    Morning Glory     Chocolate    None
# 18481       19069             1           Zinnia  Sunshine Mix     Mix
# 18844       19432             3  Cyperus papyrus          None    None
# ...           ...           ...              ...           ...     ...
# 42             57            10              NaN           NaN     NaN
# 43             58             8              NaN           NaN     NaN
# 44             59            10              NaN           NaN     NaN
# 45             60             8              NaN           NaN     NaN
# 115           132             5              NaN           NaN     NaN
#
#                DatePlanted PlantingComments  ItemID   UnitType  \
# 18482  2020-06-01 00:00:00             None    1605  Pack Tray
# 18479  2020-05-31 00:00:00             None    1631  Pack Tray
# 18480  2020-05-31 00:00:00             None    7937  Pack Tray
# 18481  2020-05-31 00:00:00             None    7739  Pack Tray
# 18844  2020-05-31 00:00:00             None    4759       Tray
# ...                    ...              ...     ...        ...
# 42     2002-03-04 00:00:00             None    2426     Hanger
# 43     2002-03-04 00:00:00             None    2426     Hanger
# 44     2002-03-04 00:00:00             None    2433     Hanger
# 45     2002-03-04 00:00:00             None    2433     Hanger
# 115    2002-03-04 00:00:00             None    2120       Tray
#
#              UnitSize UnitCategory
# 18482            1004        Packs
# 18479            1004        Packs
# 18480            1004        Packs
# 18481            1004        Packs
# 18844            1545        Trays
# ...               ...          ...
# 42     10" super trad      Hangers
# 43            10" reg      Hangers
# 44     10" super trad      Hangers
# 45            10" reg      Hangers
# 115              1545        Trays
#
# [19098 rows x 11 columns]

# %%
for item in plant_lst_columns:
    print(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for item in plant_lst_columns:
#       2     print(item)
#
# NameError: name 'plant_lst_columns' is not defined

# %%
label, sun = edgewater.get_label_display()
# Out:
# 2025-12-06 14:35:34,378 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:34,395 INFO sqlalchemy.engine.Engine SELECT `T_Items`.`ItemID` AS `T_Items_ItemID`, `T_Items`.`Inactive` AS `T_Items_Inactive`, `T_Items`.`Item` AS `T_Items_Item`, `T_Items`.`Variety` AS `T_Items_Variety`, `T_Items`.`Color` AS `T_Items_Color`, `T_Items`.`ShouldStock` AS `T_Items_ShouldStock`, `T_Items`.`TypeID` AS `T_Items_TypeID`, `T_Items`.`LabelDescription` AS `T_Items_LabelDescription`, `T_Items`.`Definition` AS `T_Items_Definition`, `T_Items`.`PictureLayout` AS `T_Items_PictureLayout`, `T_Items`.`PictureLink` AS `T_Items_PictureLink`, `T_Items`.`SunConditions` AS `T_Items_SunConditions`
# FROM `T_Items`
# 2025-12-06 14:35:34,395 INFO sqlalchemy.engine.Engine [cached since 0.8048s ago] {}
# 2025-12-06 14:35:34.490 | INFO     | rest.api:_get_all:146 - Retrieved 7254 records from T_Items
# 2025-12-06 14:35:34,500 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:34,521 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:34,522 INFO sqlalchemy.engine.Engine SELECT `T_Prices`.`PriceID` AS `T_Prices_PriceID`, `T_Prices`.`ItemID` AS `T_Prices_ItemID`, `T_Prices`.`UnitID` AS `T_Prices_UnitID`, `T_Prices`.`UnitPrice` AS `T_Prices_UnitPrice`, `T_Prices`.`Year` AS `T_Prices_Year`
# FROM `T_Prices`
# 2025-12-06 14:35:34,522 INFO sqlalchemy.engine.Engine [generated in 0.00027s] {}
# 2025-12-06 14:35:34.526 | INFO     | rest.api:_get_all:146 - Retrieved 70 records from T_Prices
# 2025-12-06 14:35:34,527 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:34,528 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:34,529 INFO sqlalchemy.engine.Engine SELECT `T_ItemType`.`TypeID` AS `T_ItemType_TypeID`, `T_ItemType`.`Type` AS `T_ItemType_Type`
# FROM `T_ItemType`
# 2025-12-06 14:35:34,529 INFO sqlalchemy.engine.Engine [cached since 0.7499s ago] {}
# 2025-12-06 14:35:34.530 | INFO     | rest.api:_get_all:146 - Retrieved 9 records from T_ItemType
# 2025-12-06 14:35:34,530 INFO sqlalchemy.engine.Engine COMMIT

# %%
edgewater.get_sun_conditions()
# Out:
# 2025-12-06 14:35:34,543 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:34,544 INFO sqlalchemy.engine.Engine SELECT `T_Items`.`ItemID` AS `T_Items_ItemID`, `T_Items`.`Inactive` AS `T_Items_Inactive`, `T_Items`.`Item` AS `T_Items_Item`, `T_Items`.`Variety` AS `T_Items_Variety`, `T_Items`.`Color` AS `T_Items_Color`, `T_Items`.`ShouldStock` AS `T_Items_ShouldStock`, `T_Items`.`TypeID` AS `T_Items_TypeID`, `T_Items`.`LabelDescription` AS `T_Items_LabelDescription`, `T_Items`.`Definition` AS `T_Items_Definition`, `T_Items`.`PictureLayout` AS `T_Items_PictureLayout`, `T_Items`.`PictureLink` AS `T_Items_PictureLink`, `T_Items`.`SunConditions` AS `T_Items_SunConditions`
# FROM `T_Items`
# 2025-12-06 14:35:34,544 INFO sqlalchemy.engine.Engine [cached since 0.9536s ago] {}
# 2025-12-06 14:35:34.643 | INFO     | rest.api:_get_all:146 - Retrieved 7254 records from T_Items
# 2025-12-06 14:35:34,654 INFO sqlalchemy.engine.Engine COMMIT
# ['all.jpg',
#  'sun.jpg',
#  'part-sun_sun.jpg',
#  'pt-sun_shade.jpg',
#  'part-sun.jpg',
#  'blank.jpg',
#  'part-sun_shade.jpg',
#  'shade.jpg',
#  'all_conditions.jpg',
#  'any',
#  None]

# %%
all =edgewater._get_plantings_full()

for col in all.columns:
    print(col)
# Out:
# 2025-12-06 14:35:34,681 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:34,683 INFO sqlalchemy.engine.Engine SELECT `T_Plantings`.`PlantingID` AS `T_Plantings_PlantingID`, `T_Plantings`.`DatePlanted` AS `T_Plantings_DatePlanted`, `T_Plantings`.`ItemID` AS `T_Plantings_ItemID`, `T_Plantings`.`UnitID` AS `T_Plantings_UnitID`, `T_Plantings`.`NumberOfUnits` AS `T_Plantings_NumberOfUnits`, `T_Plantings`.`PlantingComments` AS `T_Plantings_PlantingComments`
# FROM `T_Plantings`
# 2025-12-06 14:35:34,683 INFO sqlalchemy.engine.Engine [generated in 0.00030s] {}
# 2025-12-06 14:35:34.974 | INFO     | rest.api:_get_all:146 - Retrieved 19098 records from T_Plantings
# 2025-12-06 14:35:34,997 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:35,037 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:35,037 INFO sqlalchemy.engine.Engine SELECT `T_Items`.`ItemID` AS `T_Items_ItemID`, `T_Items`.`Inactive` AS `T_Items_Inactive`, `T_Items`.`Item` AS `T_Items_Item`, `T_Items`.`Variety` AS `T_Items_Variety`, `T_Items`.`Color` AS `T_Items_Color`, `T_Items`.`ShouldStock` AS `T_Items_ShouldStock`, `T_Items`.`TypeID` AS `T_Items_TypeID`, `T_Items`.`LabelDescription` AS `T_Items_LabelDescription`, `T_Items`.`Definition` AS `T_Items_Definition`, `T_Items`.`PictureLayout` AS `T_Items_PictureLayout`, `T_Items`.`PictureLink` AS `T_Items_PictureLink`, `T_Items`.`SunConditions` AS `T_Items_SunConditions`
# FROM `T_Items`
# 2025-12-06 14:35:35,037 INFO sqlalchemy.engine.Engine [cached since 1.447s ago] {}
# 2025-12-06 14:35:35.091 | INFO     | rest.api:_get_all:146 - Retrieved 7254 records from T_Items
# 2025-12-06 14:35:35,101 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:35,119 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:35,120 INFO sqlalchemy.engine.Engine SELECT `T_Units`.`UnitID` AS `T_Units_UnitID`, `T_Units`.`UnitType` AS `T_Units_UnitType`, `T_Units`.`UnitSize` AS `T_Units_UnitSize`, `T_Units`.`UnitCategoryID` AS `T_Units_UnitCategoryID`
# FROM `T_Units`
# 2025-12-06 14:35:35,120 INFO sqlalchemy.engine.Engine [cached since 1.352s ago] {}
# 2025-12-06 14:35:35.121 | INFO     | rest.api:_get_all:146 - Retrieved 61 records from T_Units
# 2025-12-06 14:35:35,122 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:35,123 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:35,123 INFO sqlalchemy.engine.Engine SELECT `T_UnitCategory`.`UnitCategoryID` AS `T_UnitCategory_UnitCategoryID`, `T_UnitCategory`.`UnitCategory` AS `T_UnitCategory_UnitCategory`
# FROM `T_UnitCategory`
# 2025-12-06 14:35:35,123 INFO sqlalchemy.engine.Engine [cached since 1.349s ago] {}
# 2025-12-06 14:35:35.124 | INFO     | rest.api:_get_all:146 - Retrieved 4 records from T_UnitCategory
# 2025-12-06 14:35:35,125 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:35.136 | ERROR    | rest.api:_get_plantings_full:415 - Error retrieving Inventory List: 'UnitCategory'

# %%
planting_cols = [
    "PlantingID",
    "UnitID",
    "PlantingComments",
    "ItemID",
    "DatePlanted",
    "NumberOfUnits",
    "Inactive",
    "Item",
    "Color",
    "TypeID",
    "Definition",
    "PictureLink",
    "Variety",
    "ShouldStock",
    "LabelDescription",
    "PictureLayout",
    "SunConditions",
    "UnitCategoryID",
    "UnitCategory",
]

# %%
edgewater.get_plantings_display()
# Out:
# 2025-12-06 14:35:35,147 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:35,148 INFO sqlalchemy.engine.Engine SELECT `T_Plantings`.`PlantingID` AS `T_Plantings_PlantingID`, `T_Plantings`.`DatePlanted` AS `T_Plantings_DatePlanted`, `T_Plantings`.`ItemID` AS `T_Plantings_ItemID`, `T_Plantings`.`UnitID` AS `T_Plantings_UnitID`, `T_Plantings`.`NumberOfUnits` AS `T_Plantings_NumberOfUnits`, `T_Plantings`.`PlantingComments` AS `T_Plantings_PlantingComments`
# FROM `T_Plantings`
# 2025-12-06 14:35:35,148 INFO sqlalchemy.engine.Engine [cached since 0.4653s ago] {}
# 2025-12-06 14:35:35.378 | INFO     | rest.api:_get_all:146 - Retrieved 19098 records from T_Plantings
# 2025-12-06 14:35:35,402 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:35,441 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:35,442 INFO sqlalchemy.engine.Engine SELECT `T_Items`.`ItemID` AS `T_Items_ItemID`, `T_Items`.`Inactive` AS `T_Items_Inactive`, `T_Items`.`Item` AS `T_Items_Item`, `T_Items`.`Variety` AS `T_Items_Variety`, `T_Items`.`Color` AS `T_Items_Color`, `T_Items`.`ShouldStock` AS `T_Items_ShouldStock`, `T_Items`.`TypeID` AS `T_Items_TypeID`, `T_Items`.`LabelDescription` AS `T_Items_LabelDescription`, `T_Items`.`Definition` AS `T_Items_Definition`, `T_Items`.`PictureLayout` AS `T_Items_PictureLayout`, `T_Items`.`PictureLink` AS `T_Items_PictureLink`, `T_Items`.`SunConditions` AS `T_Items_SunConditions`
# FROM `T_Items`
# 2025-12-06 14:35:35,442 INFO sqlalchemy.engine.Engine [cached since 1.851s ago] {}
# 2025-12-06 14:35:35.500 | INFO     | rest.api:_get_all:146 - Retrieved 7254 records from T_Items
# 2025-12-06 14:35:35,510 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:35,564 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:35,564 INFO sqlalchemy.engine.Engine SELECT `T_Units`.`UnitID` AS `T_Units_UnitID`, `T_Units`.`UnitType` AS `T_Units_UnitType`, `T_Units`.`UnitSize` AS `T_Units_UnitSize`, `T_Units`.`UnitCategoryID` AS `T_Units_UnitCategoryID`
# FROM `T_Units`
# 2025-12-06 14:35:35,564 INFO sqlalchemy.engine.Engine [cached since 1.797s ago] {}
# 2025-12-06 14:35:35.566 | INFO     | rest.api:_get_all:146 - Retrieved 61 records from T_Units
# 2025-12-06 14:35:35,567 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:35,568 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:35,568 INFO sqlalchemy.engine.Engine SELECT `T_UnitCategory`.`UnitCategoryID` AS `T_UnitCategory_UnitCategoryID`, `T_UnitCategory`.`UnitCategory` AS `T_UnitCategory_UnitCategory`
# FROM `T_UnitCategory`
# 2025-12-06 14:35:35,568 INFO sqlalchemy.engine.Engine [cached since 1.794s ago] {}
# 2025-12-06 14:35:35.569 | INFO     | rest.api:_get_all:146 - Retrieved 4 records from T_UnitCategory
# 2025-12-06 14:35:35,570 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:35.581 | ERROR    | rest.api:_get_plantings_full:415 - Error retrieving Inventory List: 'UnitCategory'
# 2025-12-06 14:35:35.584 | ERROR    | rest.api:get_plantings_display:436 - error retriving plantings subset: "None of [Index(['PlantingID', 'NumberOfUnits', 'Item', 'Variety', 'Color',\n       'DatePlanted', 'UnitID', 'PlantingComments', 'ItemID'],\n      dtype='object')] are in the [columns]"
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = edgewater._get_orders_full()
df
# Out:
# 2025-12-06 14:35:35,590 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:35,592 INFO sqlalchemy.engine.Engine SELECT `T_OrderItems`.`OrderItemID` AS `T_OrderItems_OrderItemID`, `T_OrderItems`.`OrderID` AS `T_OrderItems_OrderID`, `T_OrderItems`.`ItemID` AS `T_OrderItems_ItemID`, `T_OrderItems`.`ItemCode` AS `T_OrderItems_ItemCode`, `T_OrderItems`.`OrderItemTypeID` AS `T_OrderItems_OrderItemTypeID`, `T_OrderItems`.`Unit` AS `T_OrderItems_Unit`, `T_OrderItems`.`UnitPrice` AS `T_OrderItems_UnitPrice`, `T_OrderItems`.`NumberOfUnits` AS `T_OrderItems_NumberOfUnits`, `T_OrderItems`.`Received` AS `T_OrderItems_Received`, `T_OrderItems`.`OrderNote` AS `T_OrderItems_OrderNote`, `T_OrderItems`.`OrderComments` AS `T_OrderItems_OrderComments`, `T_OrderItems`.`Leftover` AS `T_OrderItems_Leftover`, `T_OrderItems`.`ToOrder` AS `T_OrderItems_ToOrder`
# FROM `T_OrderItems`
# 2025-12-06 14:35:35,592 INFO sqlalchemy.engine.Engine [generated in 0.00031s] {}
# 2025-12-06 14:35:36.064 | INFO     | rest.api:_get_all:146 - Retrieved 38580 records from T_OrderItems
# 2025-12-06 14:35:36,122 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:36,221 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:36,222 INFO sqlalchemy.engine.Engine SELECT `T_Orders`.`OrderID` AS `T_Orders_OrderID`, `T_Orders`.`GrowingSeasonID` AS `T_Orders_GrowingSeasonID`, `T_Orders`.`DatePlaced` AS `T_Orders_DatePlaced`, `T_Orders`.`DateDue` AS `T_Orders_DateDue`, `T_Orders`.`DateReceived` AS `T_Orders_DateReceived`, `T_Orders`.`SupplierID` AS `T_Orders_SupplierID`, `T_Orders`.`OrderNumber` AS `T_Orders_OrderNumber`, `T_Orders`.`ShipperID` AS `T_Orders_ShipperID`, `T_Orders`.`TrackingNumber` AS `T_Orders_TrackingNumber`, `T_Orders`.`OrderComments` AS `T_Orders_OrderComments`, `T_Orders`.`TotalCost` AS `T_Orders_TotalCost`, `T_Orders`.`GrowingSeason` AS `T_Orders_GrowingSeason`, `T_Orders`.`BrokerID` AS `T_Orders_BrokerID`
# FROM `T_Orders`
# 2025-12-06 14:35:36,222 INFO sqlalchemy.engine.Engine [generated in 0.00025s] {}
# 2025-12-06 14:35:36.243 | INFO     | rest.api:_get_all:146 - Retrieved 1562 records from T_Orders
# 2025-12-06 14:35:36,250 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:36,255 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:36,256 INFO sqlalchemy.engine.Engine SELECT `T_OrderItemTypes`.`OrderItemTypeID` AS `T_OrderItemTypes_OrderItemTypeID`, `T_OrderItemTypes`.`OrderItemType` AS `T_OrderItemTypes_OrderItemType`
# FROM `T_OrderItemTypes`
# 2025-12-06 14:35:36,256 INFO sqlalchemy.engine.Engine [generated in 0.00021s] {}
# 2025-12-06 14:35:36.258 | INFO     | rest.api:_get_all:146 - Retrieved 36 records from T_OrderItemTypes
# 2025-12-06 14:35:36,258 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:36,260 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:36,260 INFO sqlalchemy.engine.Engine SELECT `T_OrderNotes`.`OrderNoteID` AS `T_OrderNotes_OrderNoteID`, `T_OrderNotes`.`OrderNote` AS `T_OrderNotes_OrderNote`
# FROM `T_OrderNotes`
# 2025-12-06 14:35:36,260 INFO sqlalchemy.engine.Engine [generated in 0.00019s] {}
# 2025-12-06 14:35:36.262 | INFO     | rest.api:_get_all:146 - Retrieved 6 records from T_OrderNotes
# 2025-12-06 14:35:36,263 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:36,264 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:36,264 INFO sqlalchemy.engine.Engine SELECT `T_Brokers`.`BrokerID` AS `T_Brokers_BrokerID`, `T_Brokers`.`Broker` AS `T_Brokers_Broker`, `T_Brokers`.`BrokerComments` AS `T_Brokers_BrokerComments`
# FROM `T_Brokers`
# 2025-12-06 14:35:36,264 INFO sqlalchemy.engine.Engine [generated in 0.00019s] {}
# 2025-12-06 14:35:36.277 | INFO     | rest.api:_get_all:146 - Retrieved 3 records from T_Brokers
# 2025-12-06 14:35:36,280 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:36,292 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:36,294 INFO sqlalchemy.engine.Engine SELECT `T_Shippers`.`ShipperID` AS `T_Shippers_ShipperID`, `T_Shippers`.`Shipper` AS `T_Shippers_Shipper`, `T_Shippers`.`AccountNumber` AS `T_Shippers_AccountNumber`, `T_Shippers`.`Phone` AS `T_Shippers_Phone`, `T_Shippers`.`ContactPerson` AS `T_Shippers_ContactPerson`, `T_Shippers`.`Address1` AS `T_Shippers_Address1`, `T_Shippers`.`Address2` AS `T_Shippers_Address2`, `T_Shippers`.`City` AS `T_Shippers_City`, `T_Shippers`.`State` AS `T_Shippers_State`, `T_Shippers`.`Zip` AS `T_Shippers_Zip`, `T_Shippers`.`ShipperComments` AS `T_Shippers_ShipperComments`
# FROM `T_Shippers`
# 2025-12-06 14:35:36,294 INFO sqlalchemy.engine.Engine [generated in 0.00031s] {}
# 2025-12-06 14:35:36.296 | INFO     | rest.api:_get_all:146 - Retrieved 8 records from T_Shippers
# 2025-12-06 14:35:36,297 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:36,301 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:36,303 INFO sqlalchemy.engine.Engine SELECT `T_Suppliers`.`SupplierID` AS `T_Suppliers_SupplierID`, `T_Suppliers`.`Supplier` AS `T_Suppliers_Supplier`, `T_Suppliers`.`AccountNumber` AS `T_Suppliers_AccountNumber`, `T_Suppliers`.`Phone` AS `T_Suppliers_Phone`, `T_Suppliers`.`Fax` AS `T_Suppliers_Fax`, `T_Suppliers`.`WebSite` AS `T_Suppliers_WebSite`, `T_Suppliers`.`Email` AS `T_Suppliers_Email`, `T_Suppliers`.`ContactPerson` AS `T_Suppliers_ContactPerson`, `T_Suppliers`.`Address1` AS `T_Suppliers_Address1`, `T_Suppliers`.`Address2` AS `T_Suppliers_Address2`, `T_Suppliers`.`City` AS `T_Suppliers_City`, `T_Suppliers`.`State` AS `T_Suppliers_State`, `T_Suppliers`.`Zip` AS `T_Suppliers_Zip`, `T_Suppliers`.`SupplierComments` AS `T_Suppliers_SupplierComments`, `T_Suppliers`.`SupplierType` AS `T_Suppliers_SupplierType`
# FROM `T_Suppliers`
# 2025-12-06 14:35:36,303 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2025-12-06 14:35:36.308 | INFO     | rest.api:_get_all:146 - Retrieved 230 records from T_Suppliers
# 2025-12-06 14:35:36,309 INFO sqlalchemy.engine.Engine COMMIT
#        OrderItemID  OrderID  ItemID  OrderItemTypeID  UnitPrice  Received  \
# 38563        52376   1739.0    4799              2.0        NaN     False
# 38564        52377   1739.0    2398              2.0        NaN     False
# 38565        52378   1739.0    2398             26.0        NaN     False
# 38570        52383   1740.0    6122              7.0        0.0     False
# 38571        52385   1740.0    8893              7.0        0.0     False
# ...            ...      ...     ...              ...        ...       ...
# 14266        21700      NaN     913              7.0        0.0     False
# 14267        21701      NaN    1474              7.0        0.0     False
# 14268        21702      NaN    5867              7.0        0.0     False
# 16583        24602      NaN    2379              2.0        NaN     False
# 16986        25142      NaN    4783              0.0        0.0     False
#
#       OrderComments_x ToOrder ItemCode  Unit  ... State_y  SupplierComments  \
# 38563            None    None     None    48  ...      MA              None
# 38564            None    None     None   864  ...      MA              None
# 38565            None    None     None    50  ...      MA              None
# 38570            None    None     None   pkt  ...    None              None
# 38571            None    None     None   pkt  ...    None              None
# ...               ...     ...      ...   ...  ...     ...               ...
# 14266            None    None     None   500  ...     NaN               NaN
# 14267            None    None     None    1M  ...     NaN               NaN
# 14268            None    None     None   .25  ...     NaN               NaN
# 16583            None    None    73190    63  ...     NaN               NaN
# 16986            None    None     None  None  ...     NaN               NaN
#
#            Supplier  AccountNumber_y   Fax  Email         Address1_y  \
# 38563  Harvest Farm             None  None   None  125 Long Plain Rd
# 38564  Harvest Farm             None  None   None  125 Long Plain Rd
# 38565  Harvest Farm             None  None   None  125 Long Plain Rd
# 38570        Hudson             None  None   None               None
# 38571        Hudson             None  None   None               None
# ...             ...              ...   ...    ...                ...
# 14266           NaN              NaN   NaN    NaN                NaN
# 14267           NaN              NaN   NaN    NaN                NaN
# 14268           NaN              NaN   NaN    NaN                NaN
# 16583           NaN              NaN   NaN    NaN                NaN
# 16986           NaN              NaN   NaN    NaN                NaN
#
#                 City_y  Zip_y SupplierType
# 38563  South Deerfield  01373   Greenhouse
# 38564  South Deerfield  01373   Greenhouse
# 38565  South Deerfield  01373   Greenhouse
# 38570             None   None   Greenhouse
# 38571             None   None   Greenhouse
# ...                ...    ...          ...
# 14266              NaN    NaN          NaN
# 14267              NaN    NaN          NaN
# 14268              NaN    NaN          NaN
# 16583              NaN    NaN          NaN
# 16986              NaN    NaN          NaN
#
# [38580 rows x 54 columns]

# %%
for col in df.columns:
    print(col)
# Out:
# OrderItemID
# OrderID
# ItemID
# OrderItemTypeID
# UnitPrice
# Received
# OrderComments_x
# ToOrder
# ItemCode
# Unit
# NumberOfUnits
# OrderNote_x
# Leftover
# GrowingSeasonID
# DateDue
# SupplierID
# ShipperID
# OrderComments_y
# GrowingSeason
# DatePlaced
# DateReceived
# OrderNumber
# TrackingNumber
# TotalCost
# BrokerID
# OrderItemType
# OrderNoteID
# OrderNote_y
# BrokerComments
# Broker
# Phone_x
# Address1_x
# City_x
# Zip_x
# AccountNumber_x
# Shipper
# ContactPerson_x
# Address2_x
# State_x
# ShipperComments
# Phone_y
# WebSite
# ContactPerson_y
# Address2_y
# State_y
# SupplierComments
# Supplier
# AccountNumber_y
# Fax
# Email
# Address1_y
# City_y
# Zip_y
# SupplierType

# %%
[
    "ToOrder",
    "ItemCode",
    "ItemID",
    "Unit",
    "NumberOfUnits",
    "UnitPrice",
    "DatePlaced",
    "DateDue",
    "DateReceived",
    "Received",
    "OrderNote_x",
    "Leftover",
    "OrderItemID",
    "OrderID",
    "GrowingSeason",
    "OrderItemType",
    "OrderNumber",
    "TrackingNumber",
    "TotalCost",
    "Broker",
    "BrokerComments",
    "Shipper",
    "ShipperComments",
    "Supplier",
    "SupplierComments"
]
# Out:
# ['ToOrder',
#  'ItemCode',
#  'ItemID',
#  'Unit',
#  'NumberOfUnits',
#  'UnitPrice',
#  'DatePlaced',
#  'DateDue',
#  'DateReceived',
#  'Received',
#  'OrderNote_x',
#  'Leftover',
#  'OrderItemID',
#  'OrderID',
#  'GrowingSeason',
#  'OrderItemType',
#  'OrderNumber',
#  'TrackingNumber',
#  'TotalCost',
#  'Broker',
#  'BrokerComments',
#  'Shipper',
#  'ShipperComments',
#  'Supplier',
#  'SupplierComments']

# %%
edgewater.get_orders_display()
# Out:
# 2025-12-06 14:35:36,501 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:36,502 INFO sqlalchemy.engine.Engine SELECT `T_OrderItems`.`OrderItemID` AS `T_OrderItems_OrderItemID`, `T_OrderItems`.`OrderID` AS `T_OrderItems_OrderID`, `T_OrderItems`.`ItemID` AS `T_OrderItems_ItemID`, `T_OrderItems`.`ItemCode` AS `T_OrderItems_ItemCode`, `T_OrderItems`.`OrderItemTypeID` AS `T_OrderItems_OrderItemTypeID`, `T_OrderItems`.`Unit` AS `T_OrderItems_Unit`, `T_OrderItems`.`UnitPrice` AS `T_OrderItems_UnitPrice`, `T_OrderItems`.`NumberOfUnits` AS `T_OrderItems_NumberOfUnits`, `T_OrderItems`.`Received` AS `T_OrderItems_Received`, `T_OrderItems`.`OrderNote` AS `T_OrderItems_OrderNote`, `T_OrderItems`.`OrderComments` AS `T_OrderItems_OrderComments`, `T_OrderItems`.`Leftover` AS `T_OrderItems_Leftover`, `T_OrderItems`.`ToOrder` AS `T_OrderItems_ToOrder`
# FROM `T_OrderItems`
# 2025-12-06 14:35:36,502 INFO sqlalchemy.engine.Engine [cached since 0.9103s ago] {}
# 2025-12-06 14:35:36.940 | INFO     | rest.api:_get_all:146 - Retrieved 38580 records from T_OrderItems
# 2025-12-06 14:35:36,999 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:37,172 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:37,172 INFO sqlalchemy.engine.Engine SELECT `T_Orders`.`OrderID` AS `T_Orders_OrderID`, `T_Orders`.`GrowingSeasonID` AS `T_Orders_GrowingSeasonID`, `T_Orders`.`DatePlaced` AS `T_Orders_DatePlaced`, `T_Orders`.`DateDue` AS `T_Orders_DateDue`, `T_Orders`.`DateReceived` AS `T_Orders_DateReceived`, `T_Orders`.`SupplierID` AS `T_Orders_SupplierID`, `T_Orders`.`OrderNumber` AS `T_Orders_OrderNumber`, `T_Orders`.`ShipperID` AS `T_Orders_ShipperID`, `T_Orders`.`TrackingNumber` AS `T_Orders_TrackingNumber`, `T_Orders`.`OrderComments` AS `T_Orders_OrderComments`, `T_Orders`.`TotalCost` AS `T_Orders_TotalCost`, `T_Orders`.`GrowingSeason` AS `T_Orders_GrowingSeason`, `T_Orders`.`BrokerID` AS `T_Orders_BrokerID`
# FROM `T_Orders`
# 2025-12-06 14:35:37,173 INFO sqlalchemy.engine.Engine [cached since 0.9508s ago] {}
# 2025-12-06 14:35:37.189 | INFO     | rest.api:_get_all:146 - Retrieved 1562 records from T_Orders
# 2025-12-06 14:35:37,193 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:37,199 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:37,199 INFO sqlalchemy.engine.Engine SELECT `T_OrderItemTypes`.`OrderItemTypeID` AS `T_OrderItemTypes_OrderItemTypeID`, `T_OrderItemTypes`.`OrderItemType` AS `T_OrderItemTypes_OrderItemType`
# FROM `T_OrderItemTypes`
# 2025-12-06 14:35:37,200 INFO sqlalchemy.engine.Engine [cached since 0.9438s ago] {}
# 2025-12-06 14:35:37.201 | INFO     | rest.api:_get_all:146 - Retrieved 36 records from T_OrderItemTypes
# 2025-12-06 14:35:37,201 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:37,203 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:37,203 INFO sqlalchemy.engine.Engine SELECT `T_OrderNotes`.`OrderNoteID` AS `T_OrderNotes_OrderNoteID`, `T_OrderNotes`.`OrderNote` AS `T_OrderNotes_OrderNote`
# FROM `T_OrderNotes`
# 2025-12-06 14:35:37,204 INFO sqlalchemy.engine.Engine [cached since 0.9433s ago] {}
# 2025-12-06 14:35:37.204 | INFO     | rest.api:_get_all:146 - Retrieved 6 records from T_OrderNotes
# 2025-12-06 14:35:37,205 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:37,206 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:37,206 INFO sqlalchemy.engine.Engine SELECT `T_Brokers`.`BrokerID` AS `T_Brokers_BrokerID`, `T_Brokers`.`Broker` AS `T_Brokers_Broker`, `T_Brokers`.`BrokerComments` AS `T_Brokers_BrokerComments`
# FROM `T_Brokers`
# 2025-12-06 14:35:37,207 INFO sqlalchemy.engine.Engine [cached since 0.9424s ago] {}
# 2025-12-06 14:35:37.207 | INFO     | rest.api:_get_all:146 - Retrieved 3 records from T_Brokers
# 2025-12-06 14:35:37,208 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:37,209 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:37,209 INFO sqlalchemy.engine.Engine SELECT `T_Shippers`.`ShipperID` AS `T_Shippers_ShipperID`, `T_Shippers`.`Shipper` AS `T_Shippers_Shipper`, `T_Shippers`.`AccountNumber` AS `T_Shippers_AccountNumber`, `T_Shippers`.`Phone` AS `T_Shippers_Phone`, `T_Shippers`.`ContactPerson` AS `T_Shippers_ContactPerson`, `T_Shippers`.`Address1` AS `T_Shippers_Address1`, `T_Shippers`.`Address2` AS `T_Shippers_Address2`, `T_Shippers`.`City` AS `T_Shippers_City`, `T_Shippers`.`State` AS `T_Shippers_State`, `T_Shippers`.`Zip` AS `T_Shippers_Zip`, `T_Shippers`.`ShipperComments` AS `T_Shippers_ShipperComments`
# FROM `T_Shippers`
# 2025-12-06 14:35:37,210 INFO sqlalchemy.engine.Engine [cached since 0.9159s ago] {}
# 2025-12-06 14:35:37.211 | INFO     | rest.api:_get_all:146 - Retrieved 8 records from T_Shippers
# 2025-12-06 14:35:37,211 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:37,212 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:37,213 INFO sqlalchemy.engine.Engine SELECT `T_Suppliers`.`SupplierID` AS `T_Suppliers_SupplierID`, `T_Suppliers`.`Supplier` AS `T_Suppliers_Supplier`, `T_Suppliers`.`AccountNumber` AS `T_Suppliers_AccountNumber`, `T_Suppliers`.`Phone` AS `T_Suppliers_Phone`, `T_Suppliers`.`Fax` AS `T_Suppliers_Fax`, `T_Suppliers`.`WebSite` AS `T_Suppliers_WebSite`, `T_Suppliers`.`Email` AS `T_Suppliers_Email`, `T_Suppliers`.`ContactPerson` AS `T_Suppliers_ContactPerson`, `T_Suppliers`.`Address1` AS `T_Suppliers_Address1`, `T_Suppliers`.`Address2` AS `T_Suppliers_Address2`, `T_Suppliers`.`City` AS `T_Suppliers_City`, `T_Suppliers`.`State` AS `T_Suppliers_State`, `T_Suppliers`.`Zip` AS `T_Suppliers_Zip`, `T_Suppliers`.`SupplierComments` AS `T_Suppliers_SupplierComments`, `T_Suppliers`.`SupplierType` AS `T_Suppliers_SupplierType`
# FROM `T_Suppliers`
# 2025-12-06 14:35:37,213 INFO sqlalchemy.engine.Engine [cached since 0.9099s ago] {}
# 2025-12-06 14:35:37.221 | INFO     | rest.api:_get_all:146 - Retrieved 230 records from T_Suppliers
# 2025-12-06 14:35:37,238 INFO sqlalchemy.engine.Engine COMMIT
#            Supplier     Broker      Shipper DatePlaced              DateDue  \
# 38563  Harvest Farm  Edgewater  Not Shipped 2025-02-10  2025-03-24 00:00:00
# 38564  Harvest Farm  Edgewater  Not Shipped 2025-02-10  2025-03-24 00:00:00
# 38565  Harvest Farm  Edgewater  Not Shipped 2025-02-10  2025-03-24 00:00:00
# 38570        Hudson  Edgewater  Not Shipped 2025-02-10  2025-02-10 00:00:00
# 38571        Hudson  Edgewater  Not Shipped 2025-02-10  2025-02-10 00:00:00
# ...             ...        ...          ...        ...                  ...
# 14266           NaN        NaN          NaN        NaT                  NaN
# 14267           NaN        NaN          NaN        NaT                  NaN
# 14268           NaN        NaN          NaN        NaT                  NaN
# 16583           NaN        NaN          NaN        NaT                  NaN
# 16986           NaN        NaN          NaN        NaT                  NaN
#
#       DateReceived  Received ToOrder ItemCode  ItemID  ... OrderItemID  \
# 38563          NaT     False    None     None    4799  ...       52376
# 38564          NaT     False    None     None    2398  ...       52377
# 38565          NaT     False    None     None    2398  ...       52378
# 38570          NaT     False    None     None    6122  ...       52383
# 38571          NaT     False    None     None    8893  ...       52385
# ...            ...       ...     ...      ...     ...  ...         ...
# 14266          NaT     False    None     None     913  ...       21700
# 14267          NaT     False    None     None    1474  ...       21701
# 14268          NaT     False    None     None    5867  ...       21702
# 16583          NaT     False    None    73190    2379  ...       24602
# 16986          NaT     False    None     None    4783  ...       25142
#
#       OrderID  GrowingSeason   OrderItemType OrderNumber TrackingNumber  \
# 38563  1739.0           None  Rooted Cutting        None           None
# 38564  1739.0           None  Rooted Cutting        None           None
# 38565  1739.0           None         10" pot        None           None
# 38570  1740.0           None            Seed        None           None
# 38571  1740.0           None            Seed        None           None
# ...       ...            ...             ...         ...            ...
# 14266     NaN            NaN            Seed         NaN            NaN
# 14267     NaN            NaN            Seed         NaN            NaN
# 14268     NaN            NaN            Seed         NaN            NaN
# 16583     NaN            NaN  Rooted Cutting         NaN            NaN
# 16986     NaN            NaN      Unassigned         NaN            NaN
#
#       TotalCost  BrokerComments  ShipperComments SupplierComments
# 38563       0.0        Staffers             None             None
# 38564       0.0        Staffers             None             None
# 38565       0.0        Staffers             None             None
# 38570       0.0        Staffers             None             None
# 38571       0.0        Staffers             None             None
# ...         ...             ...              ...              ...
# 14266       NaN             NaN              NaN              NaN
# 14267       NaN             NaN              NaN              NaN
# 14268       NaN             NaN              NaN              NaN
# 16583       NaN             NaN              NaN              NaN
# 16986       NaN             NaN              NaN              NaN
#
# [38580 rows x 27 columns]

# %%
edgewater.get_orders_summary()
# Out:
# 2025-12-06 14:35:37,420 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:37,420 INFO sqlalchemy.engine.Engine SELECT `T_OrderItems`.`OrderItemID` AS `T_OrderItems_OrderItemID`, `T_OrderItems`.`OrderID` AS `T_OrderItems_OrderID`, `T_OrderItems`.`ItemID` AS `T_OrderItems_ItemID`, `T_OrderItems`.`ItemCode` AS `T_OrderItems_ItemCode`, `T_OrderItems`.`OrderItemTypeID` AS `T_OrderItems_OrderItemTypeID`, `T_OrderItems`.`Unit` AS `T_OrderItems_Unit`, `T_OrderItems`.`UnitPrice` AS `T_OrderItems_UnitPrice`, `T_OrderItems`.`NumberOfUnits` AS `T_OrderItems_NumberOfUnits`, `T_OrderItems`.`Received` AS `T_OrderItems_Received`, `T_OrderItems`.`OrderNote` AS `T_OrderItems_OrderNote`, `T_OrderItems`.`OrderComments` AS `T_OrderItems_OrderComments`, `T_OrderItems`.`Leftover` AS `T_OrderItems_Leftover`, `T_OrderItems`.`ToOrder` AS `T_OrderItems_ToOrder`
# FROM `T_OrderItems`
# 2025-12-06 14:35:37,421 INFO sqlalchemy.engine.Engine [cached since 1.829s ago] {}
# 2025-12-06 14:35:37.841 | INFO     | rest.api:_get_all:146 - Retrieved 38580 records from T_OrderItems
# 2025-12-06 14:35:37,900 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:38,000 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:38,001 INFO sqlalchemy.engine.Engine SELECT `T_Orders`.`OrderID` AS `T_Orders_OrderID`, `T_Orders`.`GrowingSeasonID` AS `T_Orders_GrowingSeasonID`, `T_Orders`.`DatePlaced` AS `T_Orders_DatePlaced`, `T_Orders`.`DateDue` AS `T_Orders_DateDue`, `T_Orders`.`DateReceived` AS `T_Orders_DateReceived`, `T_Orders`.`SupplierID` AS `T_Orders_SupplierID`, `T_Orders`.`OrderNumber` AS `T_Orders_OrderNumber`, `T_Orders`.`ShipperID` AS `T_Orders_ShipperID`, `T_Orders`.`TrackingNumber` AS `T_Orders_TrackingNumber`, `T_Orders`.`OrderComments` AS `T_Orders_OrderComments`, `T_Orders`.`TotalCost` AS `T_Orders_TotalCost`, `T_Orders`.`GrowingSeason` AS `T_Orders_GrowingSeason`, `T_Orders`.`BrokerID` AS `T_Orders_BrokerID`
# FROM `T_Orders`
# 2025-12-06 14:35:38,001 INFO sqlalchemy.engine.Engine [cached since 1.779s ago] {}
# 2025-12-06 14:35:38.048 | INFO     | rest.api:_get_all:146 - Retrieved 1562 records from T_Orders
# 2025-12-06 14:35:38,052 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:38,058 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:38,059 INFO sqlalchemy.engine.Engine SELECT `T_OrderItemTypes`.`OrderItemTypeID` AS `T_OrderItemTypes_OrderItemTypeID`, `T_OrderItemTypes`.`OrderItemType` AS `T_OrderItemTypes_OrderItemType`
# FROM `T_OrderItemTypes`
# 2025-12-06 14:35:38,059 INFO sqlalchemy.engine.Engine [cached since 1.803s ago] {}
# 2025-12-06 14:35:38.060 | INFO     | rest.api:_get_all:146 - Retrieved 36 records from T_OrderItemTypes
# 2025-12-06 14:35:38,060 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:38,062 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:38,062 INFO sqlalchemy.engine.Engine SELECT `T_OrderNotes`.`OrderNoteID` AS `T_OrderNotes_OrderNoteID`, `T_OrderNotes`.`OrderNote` AS `T_OrderNotes_OrderNote`
# FROM `T_OrderNotes`
# 2025-12-06 14:35:38,062 INFO sqlalchemy.engine.Engine [cached since 1.802s ago] {}
# 2025-12-06 14:35:38.063 | INFO     | rest.api:_get_all:146 - Retrieved 6 records from T_OrderNotes
# 2025-12-06 14:35:38,063 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:38,065 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:38,065 INFO sqlalchemy.engine.Engine SELECT `T_Brokers`.`BrokerID` AS `T_Brokers_BrokerID`, `T_Brokers`.`Broker` AS `T_Brokers_Broker`, `T_Brokers`.`BrokerComments` AS `T_Brokers_BrokerComments`
# FROM `T_Brokers`
# 2025-12-06 14:35:38,065 INFO sqlalchemy.engine.Engine [cached since 1.801s ago] {}
# 2025-12-06 14:35:38.066 | INFO     | rest.api:_get_all:146 - Retrieved 3 records from T_Brokers
# 2025-12-06 14:35:38,066 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:38,068 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:38,068 INFO sqlalchemy.engine.Engine SELECT `T_Shippers`.`ShipperID` AS `T_Shippers_ShipperID`, `T_Shippers`.`Shipper` AS `T_Shippers_Shipper`, `T_Shippers`.`AccountNumber` AS `T_Shippers_AccountNumber`, `T_Shippers`.`Phone` AS `T_Shippers_Phone`, `T_Shippers`.`ContactPerson` AS `T_Shippers_ContactPerson`, `T_Shippers`.`Address1` AS `T_Shippers_Address1`, `T_Shippers`.`Address2` AS `T_Shippers_Address2`, `T_Shippers`.`City` AS `T_Shippers_City`, `T_Shippers`.`State` AS `T_Shippers_State`, `T_Shippers`.`Zip` AS `T_Shippers_Zip`, `T_Shippers`.`ShipperComments` AS `T_Shippers_ShipperComments`
# FROM `T_Shippers`
# 2025-12-06 14:35:38,068 INFO sqlalchemy.engine.Engine [cached since 1.774s ago] {}
# 2025-12-06 14:35:38.069 | INFO     | rest.api:_get_all:146 - Retrieved 8 records from T_Shippers
# 2025-12-06 14:35:38,070 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:35:38,071 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:35:38,071 INFO sqlalchemy.engine.Engine SELECT `T_Suppliers`.`SupplierID` AS `T_Suppliers_SupplierID`, `T_Suppliers`.`Supplier` AS `T_Suppliers_Supplier`, `T_Suppliers`.`AccountNumber` AS `T_Suppliers_AccountNumber`, `T_Suppliers`.`Phone` AS `T_Suppliers_Phone`, `T_Suppliers`.`Fax` AS `T_Suppliers_Fax`, `T_Suppliers`.`WebSite` AS `T_Suppliers_WebSite`, `T_Suppliers`.`Email` AS `T_Suppliers_Email`, `T_Suppliers`.`ContactPerson` AS `T_Suppliers_ContactPerson`, `T_Suppliers`.`Address1` AS `T_Suppliers_Address1`, `T_Suppliers`.`Address2` AS `T_Suppliers_Address2`, `T_Suppliers`.`City` AS `T_Suppliers_City`, `T_Suppliers`.`State` AS `T_Suppliers_State`, `T_Suppliers`.`Zip` AS `T_Suppliers_Zip`, `T_Suppliers`.`SupplierComments` AS `T_Suppliers_SupplierComments`, `T_Suppliers`.`SupplierType` AS `T_Suppliers_SupplierType`
# FROM `T_Suppliers`
# 2025-12-06 14:35:38,071 INFO sqlalchemy.engine.Engine [cached since 1.768s ago] {}
# 2025-12-06 14:35:38.074 | INFO     | rest.api:_get_all:146 - Retrieved 230 records from T_Suppliers
# 2025-12-06 14:35:38,075 INFO sqlalchemy.engine.Engine COMMIT
#       OrderID                     Supplier     Broker      Shipper DatePlaced  \
# 1539   1740.0                       Hudson  Edgewater  Not Shipped 2025-02-10
# 1538   1739.0                 Harvest Farm  Edgewater  Not Shipped 2025-02-10
# 1537   1738.0  Dickman Farms & Greenhouses       Ball  Not Shipped 2024-12-18
# 1536   1737.0                       Select  Edgewater  Not Shipped 2024-12-18
# 1535   1736.0               Johnny's (JSS)  Edgewater  Not Shipped 2024-12-18
# ...       ...                          ...        ...          ...        ...
# 291     363.0                     Michells       None  Not Shipped        NaT
# 361     437.0           Van Berkum Nursery       None  Not Shipped        NaT
# 574     674.0               Van Dewetering       None  Not Shipped        NaT
# 646     755.0            Kitazawa Seed Co.       None  Not Shipped        NaT
# 959    1098.0                   De Vroomen       None  Not Shipped        NaT
#
#                   DateDue DateReceived  Received OrderNumber TrackingNumber  \
# 1539  2025-02-10 00:00:00          NaT     False        None           None
# 1538  2025-03-24 00:00:00          NaT     False        None           None
# 1537  2025-03-17 00:00:00          NaT     False     9005011           None
# 1536                 None          NaT     False        None           None
# 1535                 None          NaT     False        None           None
# ...                   ...          ...       ...         ...            ...
# 291                  None          NaT     False        None           None
# 361                  None          NaT     False        None           None
# 574   2011-04-04 00:00:00          NaT     False     3418614           None
# 646   2012-02-14 00:00:00          NaT     False        None           None
# 959   2017-03-28 00:00:00          NaT     False    V0171976           None
#
#       TotalCost GrowingSeason  UniqueItems OrderComments BrokerComments  \
# 1539        0.0          None            5          None       Staffers
# 1538        0.0          None            3          None       Staffers
# 1537        0.0          None            6          None    Lady Broker
# 1536        0.0          None           26          None       Staffers
# 1535        0.0          None           32          None       Staffers
# ...         ...           ...          ...           ...            ...
# 291         0.0          None            1          None           None
# 361         0.0          None           23          None           None
# 574         0.0          None            3          None           None
# 646         0.0          None            3          None           None
# 959         0.0          None            1          None           None
#
#      ShipperComments SupplierComments
# 1539            None             None
# 1538            None             None
# 1537            None             None
# 1536            None             None
# 1535            None             None
# ...              ...              ...
# 291             None             None
# 361             None             None
# 574             None             None
# 646             None             None
# 959             None             None
#
# [1540 rows x 17 columns]
